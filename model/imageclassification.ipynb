# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('/content/drive/MyDrive/Project/model/test_images/Dwayne Johnson Addresses Vin Diesel....jpg')
img.shape
# Out:
# (1500, 1500, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (1500, 1500)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades +"haarcascade_eye.xml")

faces = face_cascade.detectMultiScale(gray,  1.3, 5, 0)
faces
# Out:
# array([[575,  74, 333, 333]], dtype=int32)

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (575, 74, 333, 333)

# %%
faceimg = cv2.rectangle(gray,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(faceimg)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    faceimg = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = faceimg[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(faceimg, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (333, 333, 3)

# %% [markdown]
# Preprocessing: Use wavelet transform as a feature for traning our model

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %% [markdown]
# Preprocessing: Load image, detect face. If eyes >=2, then save and crop the face region

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('/content/drive/MyDrive/Project/model/test_images/Dwayne Johnson Addresses Vin Diesel....jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('/content/drive/MyDrive/Project/model/test_images/Dwayne Johnson Addresses Vin Diesel....jpg')
plt.imshow(cropped_image)

# %% [markdown]
# In below image face is not very clear and it doesn't have two eyes clearly visible

# %%
org_image_obstructed = cv2.imread('/content/drive/MyDrive/Project/model/test_images/Dwayne Johnson accuses Vin Diesel of....jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('/content/drive/MyDrive/Project/model/test_images/Dwayne Johnson accuses Vin Diesel of....jpg')
cropped_image_no_2_eyes

# %%
path_to_data = "/content/drive/MyDrive/Project/model/dataset"
path_to_cr_data = "/content/drive/MyDrive/Project/model/dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['/content/drive/MyDrive/Project/model/dataset/messi',
#  '/content/drive/MyDrive/Project/model/dataset/dwane_johnson',
#  '/content/drive/MyDrive/Project/model/dataset/gal_gadot',
#  '/content/drive/MyDrive/Project/model/dataset/virat_kohli',
#  '/content/drive/MyDrive/Project/model/dataset/priyanka_chopra']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  /content/drive/MyDrive/Project/model/dataset/cropped/messi
# Generating cropped images in folder:  /content/drive/MyDrive/Project/model/dataset/cropped/dwane_johnson
# Generating cropped images in folder:  /content/drive/MyDrive/Project/model/dataset/cropped/gal_gadot
# Generating cropped images in folder:  /content/drive/MyDrive/Project/model/dataset/cropped/virat_kohli
# Generating cropped images in folder:  /content/drive/MyDrive/Project/model/dataset/cropped/priyanka_chopra
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-31-d48fa3e899f7> in <module>()
#       6     celebrity_file_names_dict[celebrity_name] = []
#       7     for entry in os.scandir(img_dir):
# ----> 8         roi_color = get_cropped_image_if_2_eyes(entry.path)
#       9         if roi_color is not None:
# ...

# %% [markdown]
# Manually examine cropped folder and delete any unwanted images

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'dwane_johnson': ['/content/drive/MyDrive/Project/model/dataset/cropped/dwane_johnson/dwane_johnson1.png',
#   '/content/drive/MyDrive/Project/model/dataset/cropped/dwane_johnson/dwane_johnson2.png',
#   '/content/drive/MyDrive/Project/model/dataset/cropped/dwane_johnson/dwane_johnson3.png',
#   '/content/drive/MyDrive/Project/model/dataset/cropped/dwane_johnson/dwane_johnson4.png',
#   '/content/drive/MyDrive/Project/model/dataset/cropped/dwane_johnson/dwane_johnson5.png',
#   '/content/drive/MyDrive/Project/model/dataset/cropped/dwane_johnson/dwane_johnson6.png',
#   '/content/drive/MyDrive/Project/model/dataset/cropped/dwane_johnson/dwane_johnson7.png',
#   '/content/drive/MyDrive/Project/model/dataset/cropped/dwane_johnson/dwane_johnson8.png',
#   '/content/drive/MyDrive/Project/model/dataset/cropped/dwane_johnson/dwane_johnson9.png',
#   '/content/drive/MyDrive/Project/model/dataset/cropped/dwane_johnson/dwane_johnson10.png',
# ...

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'dwane_johnson': 1,
#  'gal_gadot': 2,
#  'messi': 0,
#  'priyanka_chopra': 4,
#  'virat_kohli': 3}

# %% [markdown]
# Images in cropped folder can be used for model training. We will use these raw images along with wavelet transformed images to train our classifier. Let's prepare X and y now

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
X[0]
# Out:
# array([[141],
#        [141],
#        [153],
#        ...,
#        [ 75],
#        [163],
#        [134]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (431, 4096)

# %% [markdown]
# Data cleaning process is done. Now we are ready to train our model

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.8240740740740741

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.97      0.90        31
#            1       1.00      0.52      0.69        21
#            2       0.64      0.60      0.62        15
#            3       1.00      1.00      1.00         6
#            4       0.80      0.94      0.87        35
#
#     accuracy                           0.82       108
#    macro avg       0.86      0.81      0.81       108
# weighted avg       0.84      0.82      0.81       108

# %% [markdown]
# applied GridSearch to try out different models with different paramets.  to come up with best modle with best fine tuned parameters

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.863558
# 1        random_forest    0.758606
# 2  logistic_regression    0.851250
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.8703703703703703

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.7129629629629629

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.8981481481481481

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[30,  0,  0,  0,  1],
#        [ 2, 16,  1,  0,  2],
#        [ 2,  2,  9,  0,  2],
#        [ 0,  0,  0,  6,  0],
#        [ 0,  1,  1,  0, 33]])

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'dwane_johnson': 1,
#  'gal_gadot': 2,
#  'messi': 0,
#  'priyanka_chopra': 4,
#  'virat_kohli': 3}

# %%
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
